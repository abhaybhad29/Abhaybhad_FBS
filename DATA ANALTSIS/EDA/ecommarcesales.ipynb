# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv("C:/Users/ABHAY BHAD/Downloads/ecommerce_sales_eda_dataset.csv")
df
# Out:
#     Order_ID  Customer_Age  Gender     Category     Product  Quantity  Price  \
# 0       1001            22    Male  Electronics      Laptop         1  55000
# 1       1002            28  Female     Clothing     T-Shirt         3    799
# 2       1003            35    Male  Electronics      Mobile         2  25000
# 3       1004            24  Female       Beauty  Face Cream         2    599
# 4       1005            31    Male    Furniture       Chair         4   1500
# 5       1006            27  Female  Electronics  Headphones         2   1999
# 6       1007            40    Male     Clothing       Jeans         2   1899
# 7       1008            23  Female  Electronics  Smartwatch         1   4999
# 8       1009            36    Male       Beauty     Perfume         3   1299
# 9       1010            29  Female    Furniture       Table         1   7500
# 10      1011            25    Male  Electronics    Keyboard         2   1299
# ...

# %% [markdown]
# #### 1. First 5 rows

# %%
df.head()
# Out:
#    Order_ID  Customer_Age  Gender     Category     Product  Quantity  Price  \
# 0      1001            22    Male  Electronics      Laptop         1  55000
# 1      1002            28  Female     Clothing     T-Shirt         3    799
# 2      1003            35    Male  Electronics      Mobile         2  25000
# 3      1004            24  Female       Beauty  Face Cream         2    599
# 4      1005            31    Male    Furniture       Chair         4   1500
#
#    Discount Payment    City  Order_Date  Rating  Sales
# 0         5     UPI    Pune  2025-01-05       4  55000
# 1        10    Card  Mumbai  2025-01-07       5   2397
# 2         8    Cash  Nagpur  2025-01-10       4  50000
# 3         5     UPI    Pune  2025-01-12       3   1198
# 4        12    Card  Nashik  2025-01-15       4   6000

# %% [markdown]
# ### 2. Last 5 rows

# %%
df.tail()
# Out:
#     Order_ID  Customer_Age  Gender     Category    Product  Quantity  Price  \
# 15      1016            30  Female     Clothing      Dress         2   2499
# 16      1017            45    Male    Furniture        Bed         1  35000
# 17      1018            24  Female  Electronics      Mouse         3    799
# 18      1019            32    Male       Beauty  Face Wash         2    399
# 19      1020            28  Female     Clothing      Shoes         1   3499
#
#     Discount Payment    City  Order_Date  Rating  Sales
# 15         8    Card    Pune  2025-02-17       5   4998
# 16        12    Cash  Nashik  2025-02-20       4  35000
# 17         5     UPI  Nagpur  2025-02-23       4   2397
# 18        10    Card  Mumbai  2025-02-25       3    798
# 19        15     UPI    Pune  2025-02-28       5   3499

# %% [markdown]
# #### Dataset info

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      20 non-null     int64
#  1   Customer_Age  20 non-null     int64
#  2   Gender        20 non-null     str
#  3   Category      20 non-null     str
#  4   Product       20 non-null     str
#  5   Quantity      20 non-null     int64
#  6   Price         20 non-null     int64
#  7   Discount      20 non-null     int64
#  8   Payment       20 non-null     str
#  9   City          20 non-null     str
#  10  Order_Date    20 non-null     str
#  11  Rating        20 non-null     int64
#  12  Sales         20 non-null     int64
# dtypes: int64(7), str(6)
# memory usage: 2.2 KB

# %% [markdown]
# #### Statistical summary

# %%
df.describe()
# Out:
#          Order_ID  Customer_Age   Quantity         Price   Discount    Rating  \
# count    20.00000     20.000000  20.000000     20.000000  20.000000  20.00000
# mean   1010.50000     29.850000   1.950000   9229.350000   9.000000   4.15000
# std       5.91608      6.442254   0.998683  14625.814929   3.656285   0.74516
# min    1001.00000     21.000000   1.000000    399.000000   5.000000   3.00000
# 25%    1005.75000     24.750000   1.000000   1174.000000   5.000000   4.00000
# 50%    1010.50000     28.500000   2.000000   2249.000000   9.000000   4.00000
# 75%    1015.25000     33.500000   2.250000   8625.000000  12.000000   5.00000
# max    1020.00000     45.000000   4.000000  55000.000000  15.000000   5.00000
#
#               Sales
# count     20.000000
# mean   11503.600000
# std    16392.702181
# min      798.000000
# 25%     2547.750000
# 50%     3947.500000
# 75%     8625.000000
# max    55000.000000

# %% [markdown]
# #### Check missing values

# %%
df.isnull().sum()
# Out:
# Order_ID        0
# Customer_Age    0
# Gender          0
# Category        0
# Product         0
# Quantity        0
# Price           0
# Discount        0
# Payment         0
# City            0
# Order_Date      0
# Rating          0
# Sales           0
# dtype: int64

# %% [markdown]
# #### Check duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### check column

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Gender', 'Category', 'Product', 'Quantity',
#        'Price', 'Discount', 'Payment', 'City', 'Order_Date', 'Rating',
#        'Sales'],
#       dtype='str')

# %% [markdown]
# ### Check unique values

# %%
df.nunique()
# Out:
# Order_ID        20
# Customer_Age    18
# Gender           2
# Category         4
# Product         20
# Quantity         4
# Price           17
# Discount         5
# Payment          3
# City             4
# Order_Date      20
# Rating           3
# Sales           19
# dtype: int64

# %% [markdown]
# ### Avgrage age

# %%
df["Customer_Age"].mean()
# Out:
# np.float64(29.85)

# %% [markdown]
# ### city has the highest number of orders

# %%
df["City"].value_counts()
# Out:
# City
# Pune      7
# Mumbai    6
# Nagpur    4
# Nashik    3
# Name: count, dtype: int64

# %% [markdown]
# #### the most popular payment method

# %%
df["Payment"].value_counts()
# Out:
# Payment
# UPI     9
# Card    7
# Cash    4
# Name: count, dtype: int64

# %% [markdown]
# ### the average product rating

# %%
df["Rating"].value_counts()
# Out:
# Rating
# 4    9
# 5    7
# 3    4
# Name: count, dtype: int64

# %% [markdown]
# ### category gives the highest average rating

# %%
df.groupby("Category")["Rating"].mean()
# Out:
# Category
# Beauty         3.000000
# Clothing       4.600000
# Electronics    4.428571
# Furniture      4.250000
# Name: Rating, dtype: float64

# %% [markdown]
# ### discount affect quantity sold

# %%
df.groupby("Discount")["Quantity"].mean()
# Out:
# Discount
# 5     2.428571
# 8     1.666667
# 10    1.750000
# 12    2.000000
# 15    1.333333
# Name: Quantity, dtype: float64

# %% [markdown]
# ### Create a correlation heatmap

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Plot sales by category

# %%
sales_category = df.groupby("Category")["Sales"].sum()

sales_category.plot(kind="bar", figsize=(8,5))

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Plot orders by city

# %%
orders_city = df["City"].value_counts()

orders_city.plot(kind="bar", figsize=(8,5))

plt.title("Orders by City")
plt.xlabel("City")
plt.ylabel("Number of Orders")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Plot distribution of customer ages

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Customer_Age"], bins=8)

plt.title("Distribution of Customer Ages")
plt.xlabel("Customer Age")
plt.ylabel("Frequency")

plt.show()
