# %% [markdown]
# ##  Numpy Introduction
# 1. Extensible library
# 2. Faster than core python
# 3. Numeic - python
# 4. Mathamatical opration like arithmatic, algbra,random sampling
# 5. Array, Matrix,strings

# %% [markdown]
# ## Array Introduction
# 1. Array([])
# 2. Homogenous
# 3. Ordered
# 4. Mutable,size-Imutable
# 5. Duplicate element are allowed
# 6. Numpy array is 50x time faster than list

# %% [markdown]
# li1 = [1 ,2 , 3 , 4, 5,.............]
# li2 = [2 ,4 , 1 , 3, 7,.............]
# li3 = [3 ,6 , 4 , 7, 12,............]
# 100000 values
