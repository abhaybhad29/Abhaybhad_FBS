# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.5455404707814532

# %%
team1 = np.random.randint(0,36,20)
team1
# Out:
# array([ 7, 28, 25,  2, 17, 22, 15, 31, 21, 12, 27,  0,  7,  7,  4, 31, 32,
#        32,  9, 21], dtype=int32)

# %%
np.random.randint(0,36,(4,5))
# Out:
# array([[22, 14,  1, 23, 31],
#        [10, 28,  2, 20,  7],
#        [25, 18, 15,  3,  9],
#        [21, 22, 22, 10, 20]], dtype=int32)

# %%
np.random.seed(10)
np.random.randint(0,100,1)
# Out:
# array([9], dtype=int32)

# %%
np.random.rand()
# Out:
# 0.29876115188562824

# %%
np.random.randn(10)
# Out:
# array([-2.93119247, -0.27828276,  0.29986131,  1.19449472, -0.90561048,
#        -0.89808938,  0.45187984, -0.85947418, -0.53479453,  1.03287114])

# %%
dice = np.arange(1,7)

# %%
np.random.choice(dice,1)
# Out:
# array([1])

# %%
dice
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.random.permutation(dice)
# Out:
# array([6, 1, 2, 5, 3, 4])

# %%
np.sin(np.radians(30))
# Out:
# np.float64(0.49999999999999994)
