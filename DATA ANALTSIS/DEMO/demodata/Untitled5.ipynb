# %% [markdown]
# # PANDAS INTRODUCTION

# %% [markdown]
# 1.powerful python data analysis libraries
# 2.behind numpy arry is implemented
# 3.used for load datasets(from files eg.csv,tsv,excel etc.)

# %% [markdown]
# # Data structure

# %% [markdown]
# 1.series (1D)
# 2.DataFrame(2D)
# 3.panel(3D)
