# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Lineplot
# 1. Trend over time
# 2. Time series analysis
# 3. Upward / downword trend

# %%
import numpy as np

# %%
overs = np.arange(1,21)
MI = np.random.randint(0,37,20)
CSK = np.random.randint(0,37,20)

# %%
MI
# Out:
# array([33, 14, 33, 34, 27,  3, 14, 18,  2, 17,  7,  1,  2, 22, 12, 33, 10,
#        19, 31,  0], dtype=int32)

# %%
MI_score = np.cumsum(MI)
MI_score
# Out:
# array([ 33,  47,  80, 114, 141, 144, 158, 176, 178, 195, 202, 203, 205,
#        227, 239, 272, 282, 301, 332, 332])

# %%
CSK_score = np.cumsum(CSK)
CSK_score
# Out:
# array([  4,  20,  20,  44,  52,  87,  88,  97, 102, 120, 152, 182, 216,
#        243, 271, 305, 313, 321, 338, 352])

# %%
plt.figure(figsize=(7,3))

# Only 2 lines
plt.plot(overs, MI_score,  label='MI')
plt.plot(overs, CSK_score, label='CSK')


# Mark MI wickets only when a new wicket falls
for i in range(1, len(overs)):
    if MI_wickets[i] > MI_wickets[i-1]:
        plt.scatter(overs[i], MI_score[i],
                    marker='x', s=100, linewidths=3)
        plt.text(overs[i], MI_score[i] + 10, 'W',
                 ha='center', fontweight='bold')


# Mark CSK wickets only when a new wicket falls
for i in range(1, len(overs)):
    if CSK_wickets[i] > CSK_wickets[i-1]:
        plt.scatter(overs[i], CSK_score[i],
                    marker='x', s=100, linewidths=3)
        plt.text(overs[i], CSK_score[i] + 10, 'W',
                 ha='center', fontweight='bold')


plt.xlabel('Overs')
plt.ylabel('Score')
plt.title('Match Summary')
plt.legend()
plt.show()

# %% [markdown]
# ## Scatterplot
# 1. Relationship between two variable
# 2. Correlation
# 3. Positive correlation
# 4. Negative correlation

# %%
plt.figure(figsize=(7,3))
plt.scatter(overs, MI, marker='o',color='blue',label='MI')
plt.scatter(overs,CSK, marker="<",color="yellow",label='CSK')
plt.legend()
plt.show()

# %% [markdown]
# # Pie chart
# 1. showing percentage distribution
# 2. part to whole comparision
# 3. best to use when categories <=5

# %%
marks = [70,90,67,40,76,72]
subjects = ['m1', 'm2', 'm3','m4','m5','m6']
plt.pie(marks, labels=subjects, autopct = '%0.2f%%')
plt.show()

# %% [markdown]
# ## Boxplot
# 1. summary of distribution
# 2. check outlier

# %%
plt.figure(figsize=(7,3))
age = [1,2,3,4,5,6,7,8,14]
plt.boxplot(age)
plt.show()
