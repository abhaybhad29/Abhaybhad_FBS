# %%
import pandas as pd

# %% [markdown]
# 1. pd.Series()
# 2. Heterogeous
# 3. ordered
# 4. Mutable, size - Immutable
# 5. Duplicate allowed
# 6. Customized indexing avaiable

# %%
s1 = pd.Series([10,20,30,'abc',30])
s1
# Out:
# 0     10
# 1     20
# 2     30
# 3    abc
# 4     30
# dtype: object

# %%
s1 = pd.Series([10,20,30,40],index = ['a','b','c','d'])
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s2 = pd.Series([50,60,70,80], index = ['c','d','e','f'])
s2
# Out:
# c    50
# d    60
# e    70
# f    80
# dtype: int64

# %%
s1 +s2
# Out:
# a      NaN
# b      NaN
# c     80.0
# d    100.0
# e      NaN
# f      NaN
# dtype: float64

# %%
s1.sum()
# Out:
# np.int64(100)

# %%
s1.mean()
# Out:
# np.float64(25.0)

# %%
s1.median()
# Out:
# np.float64(25.0)

# %%
s1.std()
# Out:
# np.float64(12.909944487358056)

# %%
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s1.loc['a']
# Out:
# np.int64(10)

# %%
s1.iloc[0]
# Out:
# np.int64(10)
