# %% [markdown]
# ## Dataframe introduction
# 1. DataFrame()
# 2. Heterogeneous
# 3. ordered
# 4. Mutable, Size - Mutable
# 5. Duplication Allowed
# 6. 2D datastructure of pandas
# 7. Row and columns

# %%
import pandas as pd

# %%
df = pd.DataFrame()
type(df)
# Out:
# pandas.DataFrame

# %%
df = pd.DataFrame([[101,'Akshay',500000],
                   [102,'kartik',456744],
                   [103,'oalak',5543454]] ,
                  columns=['ID','NAME','SAL'])
df
# Out:
#     ID    NAME      SAL
# 0  101  Akshay   500000
# 1  102  kartik   456744
# 2  103   oalak  5543454

# %%
df2 = pd.DataFrame({'ID':[101,102,103],
                    'Name':['Akshay','sagar','Rohit'],
                    'sal':[60000, 50000 , 47363]})
df2
# Out:
#     ID    Name    sal
# 0  101  Akshay  60000
# 1  102   sagar  50000
# 2  103   Rohit  47363

# %%
df3 = df.set_index('ID')

# %%
df3
# Out:
#        NAME      SAL
# ID
# 101  Akshay   500000
# 102  kartik   456744
# 103   oalak  5543454

# %%
df3.loc[101:102]
# Out:
#        NAME     SAL
# ID
# 101  Akshay  500000
# 102  kartik  456744

# %%
df3.iloc[0:2]
# Out:
#        NAME     SAL
# ID
# 101  Akshay  500000
# 102  kartik  456744

# %%
iris = pd.read_csv("D:/Documents/Iris.csv")
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.tail()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
iris.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['Sepal_Length'].agg(['mean','max','min','sum'])
# Out:
# mean      5.843333
# max       7.900000
# min       4.300000
# sum     876.500000
# Name: Sepal_Length, dtype: float64

# %%
iris['Species'].unique()
# Out:
# <StringArray>
# ['Setosa', 'Versicolor', 'Virginica']
# Length: 3, dtype: str

# %%
iris['Species'].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.drop('Species',axis = 1,inplace=True)

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.drop(0,inplace=True) #remove first row use information to change in original

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4

# %%
df['Address'] = ['pune' , 'mumbai', 'delhi'] #add column

# %%
df
# Out:
#     ID    NAME      SAL Address
# 0  101  Akshay   500000    pune
# 1  102  kartik   456744  mumbai
# 2  103   oalak  5543454   delhi

# %%
df.loc[3] = [104,'Abhi','8754789','pune'] # forr add roww

# %%
df
# Out:
#     ID    NAME      SAL Address
# 0  101  Akshay   500000    pune
# 1  102  kartik   456744  mumbai
# 2  103   oalak  5543454   delhi
# 3  104    Abhi  8754789    pune
